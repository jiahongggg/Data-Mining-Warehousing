# %%
pip install featuretools
# Out:
# Requirement already satisfied: featuretools in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (1.28.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (2.2.1)
# Requirement already satisfied: holidays<0.33,>=0.13 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (0.32)
# Requirement already satisfied: numpy>=1.21.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (23.0)
# Requirement already satisfied: pandas>=1.5.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (5.9.0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (1.10.1)
# Requirement already satisfied: tqdm>=4.32.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (4.65.0)
# Requirement already satisfied: woodwork>=0.23.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from featuretools) (0.26.0)
# Requirement already satisfied: python-dateutil in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from holidays<0.33,>=0.13->featuretools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.0->featuretools) (2022.7)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from woodwork>=0.23.0->featuretools) (1.3.0)
# Requirement already satisfied: importlib-resources>=5.10.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from woodwork>=0.23.0->featuretools) (6.1.1)
# Requirement already satisfied: six>=1.5 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from python-dateutil->holidays<0.33,>=0.13->featuretools) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22->woodwork>=0.23.0->featuretools) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/simjiahong/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22->woodwork>=0.23.0->featuretools) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import featuretools as ft
import pandas as pd

# %%
# Sample data
customers_data = {
    'CustomerID': [101, 102, 103],
    'Name': ['John Doe', 'Jane Smith', 'Mike Jordan'],
    'Email': ['john.doe@example.com', 'jane.smith@example.com', 'mike.jordan@example.com'],
    'SignupDate': ['2023-01-10', '2023-01-15', '2023-01-20']
}
products_data = {
    'ProductID': [201, 202, 203],
    'Name': ['Laptop', 'Tablet', 'Smartphone'],
    'Category': ['Electronics', 'Electronics', 'Electronics'],
    'Price': [1000, 500, 800]
}
orders_data = {
    'OrderID': [301, 302, 303],
    'CustomerID': [101, 102, 103],
    'OrderDate': ['2023-02-01', '2023-02-05', '2023-02-10'],
    'ShipDate': ['2023-02-03', '2023-02-07', '2023-02-12']
}
order_details_data = {
    'OrderID': [301, 302, 303],
    'ProductID': [201, 202, 203],
    'Quantity': [1, 2, 1],
    'Discount': [0, 0.1, 0]
}

# %%
# Converting to DataFrames
customers_df = pd.DataFrame(customers_data)
products_df = pd.DataFrame(products_data)
orders_df = pd.DataFrame(orders_data)
order_details_df = pd.DataFrame(order_details_data)

# %%
# Creating an EntitySet
es = ft.EntitySet(id='ecommerce_data')

# %%
# Adding entities
es = es.add_dataframe(dataframe_name='customers', dataframe=customers_df, index='CustomerID')
es = es.add_dataframe(dataframe_name='products', dataframe=products_df, index='ProductID')
es = es.add_dataframe(dataframe_name='orders', dataframe=orders_df, index='OrderID')
es = es.add_dataframe(dataframe_name='order_details', dataframe=order_details_df, make_index=True, index='details_index')

# %%
# Adding relationships
es = es.add_relationship('customers','CustomerID','orders','CustomerID')
es = es.add_relationship('orders','OrderID','order_details','OrderID')
es = es.add_relationship('products','ProductID','order_details','ProductID')
es
# Out:
# Entityset: ecommerce_data
#   DataFrames:
#     customers [Rows: 3, Columns: 4]
#     products [Rows: 3, Columns: 4]
#     orders [Rows: 3, Columns: 4]
#     order_details [Rows: 3, Columns: 5]
#   Relationships:
#     orders.CustomerID -> customers.CustomerID
#     order_details.OrderID -> orders.OrderID
#     order_details.ProductID -> products.ProductID

# %%
# Deep Feature Synthesis
feature_matrix, feature_defs = ft.dfs(
    entityset=es, 
    target_dataframe_name='orders', 
    agg_primitives=["sum", "mean", "count"], 
    trans_primitives=["month", "day"], 
    max_depth=2
)
# Displaying new features
feature_matrix
# Out:
#          CustomerID  COUNT(order_details)  MEAN(order_details.Discount)  \
# OrderID
# 301             101                     1                           0.0
# 302             102                     1                           0.1
# 303             103                     1                           0.0
#
#          MEAN(order_details.Quantity)  SUM(order_details.Discount)  \
# OrderID
# 301                               1.0                          0.0
# 302                               2.0                          0.1
# 303                               1.0                          0.0
#
#          SUM(order_details.Quantity) DAY(OrderDate) DAY(ShipDate)  \
# OrderID
# 301                              1.0              1             3
# 302                              2.0              5             7
# 303                              1.0             10            12
#
#         MONTH(OrderDate) MONTH(ShipDate)  MEAN(order_details.products.Price)  \
# OrderID
# 301                    2               2                              1000.0
# 302                    2               2                               500.0
# 303                    2               2                               800.0
#
#          SUM(order_details.products.Price)  customers.COUNT(orders)  \
# OrderID
# 301                                 1000.0                        1
# 302                                  500.0                        1
# 303                                  800.0                        1
#
#          customers.COUNT(order_details)  \
# OrderID
# 301                                   1
# 302                                   1
# 303                                   1
#
#          customers.MEAN(order_details.Discount)  \
# OrderID
# 301                                         0.0
# 302                                         0.1
# 303                                         0.0
#
#          customers.MEAN(order_details.Quantity)  \
# OrderID
# 301                                         1.0
# 302                                         2.0
# 303                                         1.0
#
#          customers.SUM(order_details.Discount)  \
# OrderID
# 301                                        0.0
# 302                                        0.1
# 303                                        0.0
#
#          customers.SUM(order_details.Quantity) customers.DAY(SignupDate)  \
# OrderID
# 301                                        1.0                        10
# 302                                        2.0                        15
# 303                                        1.0                        20
#
#         customers.MONTH(SignupDate)
# OrderID
# 301                               1
# 302                               1
# 303                               1
